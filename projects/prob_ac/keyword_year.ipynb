# %%
import pandas as pd

# %%
train_df = pd.read_csv("data/train_data.csv")
test_df = pd.read_csv("data/test_data.csv")
all_df = pd.concat([train_df, test_df], axis=0).reset_index(drop=True)

# %%
from projects.prob_ac.custom.feature_generators import KeywordsLengthFeature, KeywordsAverageYear, KeywordsAverageCount, KeywordsFirstYear
from lilac.core.utils import plot_numeric_feature_hist_for_cls

# %%
gens = [KeywordsLengthFeature(), KeywordsAverageYear(), KeywordsAverageCount(), KeywordsFirstYear()] 

for gen in gens:
    gen.fit(all_df)
    train_feat = gen.transform(train_df)
    test_feat = gen.transform(test_df)
    train_df=pd.concat([train_df,train_feat],axis=1)
    test_df=pd.concat([test_df,test_feat],axis=1)

train_df
# Out:
#         id                                              title  year  \
# 0        1       Hierarchical Adversarially Learned Inference  2018
# 1        2     Learning to Compute Word Embeddings On the Fly  2018
# 2        3   Graph2Seq: Scalable Learning Dynamics for Graphs  2018
# 3        4  Generating Differentially Private Datasets Usi...  2018
# 4        5  Representing dynamically: An active process fo...  2018
# ...    ...                                                ...   ...
# 4969  4970         Convolutional Conditional Neural Processes  2020
# 4970  4971  Gradient Descent Maximizes the Margin of Homog...  2020
# 4971  4972  Adversarial Training and Provable Defenses: Br...  2020
# 4972  4973  Differentiable Reasoning over a Virtual Knowle...  2020
# 4973  4974          Federated Learning with Matched Averaging  2020
#
#                                                abstract  \
# 0     We propose a novel hierarchical generative mod...
# ...

# %%
plot_numeric_feature_hist_for_cls(train_df,test_df,"diff_years_keywords_first_and_actual","y")

# %%
plot_numeric_feature_hist_for_cls(train_df,test_df,"diff_years_keywords_avg_and_actual","y")

# %%
plot_numeric_feature_hist_for_cls(train_df,test_df,"keywords_len","y")

# %%
plot_numeric_feature_hist_for_cls(train_df,test_df,"keywords_avg_count","y")

# %%
train_df
# Out:
#         id                                              title  year  \
# 0        1       Hierarchical Adversarially Learned Inference  2018
# 1        2     Learning to Compute Word Embeddings On the Fly  2018
# 2        3   Graph2Seq: Scalable Learning Dynamics for Graphs  2018
# 3        4  Generating Differentially Private Datasets Usi...  2018
# 4        5  Representing dynamically: An active process fo...  2018
# ...    ...                                                ...   ...
# 4969  4970         Convolutional Conditional Neural Processes  2020
# 4970  4971  Gradient Descent Maximizes the Margin of Homog...  2020
# 4971  4972  Adversarial Training and Provable Defenses: Br...  2020
# 4972  4973  Differentiable Reasoning over a Virtual Knowle...  2020
# 4973  4974          Federated Learning with Matched Averaging  2020
#
#                                                abstract  \
# 0     We propose a novel hierarchical generative mod...
# ...
